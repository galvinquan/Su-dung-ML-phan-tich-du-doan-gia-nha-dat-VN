# %% [markdown]
# # EXO MACHINE LEARNING
# Phần code sử dụng các thư viện để lọc và trình bày dữ liệu và dùng ML để dự đoán giá nhà ở Hà Nội

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Lọc và chuyển dạng dữ liệu cho các data cần thiết

# %%
df = pd.read_csv('vietnam_housing_dataset.csv')
df['Floors'] = pd.to_numeric(df['Floors'], errors='coerce')
df['Floors'] = df['Floors'].astype(pd.Int64Dtype())
df['Bedrooms'] = pd.to_numeric(df['Bedrooms'], errors='coerce')
df['Bedrooms'] = df['Bedrooms'].astype(pd.Int64Dtype())
df['Bathrooms'] = pd.to_numeric(df['Bathrooms'], errors='coerce')
df['Bathrooms'] = df['Bathrooms'].astype(pd.Int64Dtype())
df['Price'] = df['Price']*1000
df['Giá/m2'] = (df['Price']/df['Area']).round(2)
df['Access Road'] = pd.to_numeric(df['Access Road'], errors='coerce')
df['Access Road'] = df['Access Road'].astype(pd.Float64Dtype())
df['Frontage'] = pd.to_numeric(df['Frontage'], errors='coerce')
df['Frontage'] = df['Frontage'].astype(pd.Float64Dtype())
df
# Out:
#                                                  Address  Area  Frontage  \
# 0      Dự án The Empire - Vinhomes Ocean Park 2, Xã L...  84.0      <NA>
# 1      Dự án The Crown - Vinhomes Ocean Park 3, Xã Ng...  60.0      <NA>
# 2      Dự án The Crown - Vinhomes Ocean Park 3, Xã Ng...  90.0       6.0
# 3      Đường Nguyễn Văn Khối, Phường 11, Gò Vấp, Hồ C...  54.0      <NA>
# 4       Đường Quang Trung, Phường 8, Gò Vấp, Hồ Chí Minh  92.0      <NA>
# ...                                                  ...   ...       ...
# 30224  Đường Lê Quang Định, Phường 1, Gò Vấp, Hồ Chí ...  67.0       4.1
# 30225  Đường Ngô Gia Tự, Phường Đức Giang, Long Biên,...  30.0      <NA>
# 30226  Đường Gò Dưa, Phường Tam Bình, Thủ Đức, Hồ Chí...  69.4       4.0
# 30227  Đường Quang Trung, Phường 11, Gò Vấp, Hồ Chí Minh  96.0      <NA>
# 30228  Đường Đại lộ Thăng Long, Xã An Khánh, Hoài Đức...  35.0      <NA>
#
#        Access Road House direction Balcony direction  Floors  Bedrooms  \
# 0             <NA>             NaN               NaN       4      <NA>
# 1             <NA>             NaN               NaN       5      <NA>
# 2             13.0      Đông - Bắc        Đông - Bắc       5      <NA>
# 3              3.5       Tây - Nam         Tây - Nam       2         2
# 4             <NA>      Đông - Nam        Đông - Nam       2         4
# ...            ...             ...               ...     ...       ...
# 30224         16.0             NaN               NaN       1         3
# 30225         <NA>             NaN               NaN       5         3
# 30226         15.0      Đông - Bắc        Đông - Bắc    <NA>      <NA>
# 30227          8.0             NaN               NaN       4      <NA>
# 30228         <NA>      Đông - Nam        Đông - Nam       5         3
#
#        Bathrooms      Legal status Furniture state   Price  Giá/m2
# 0           <NA>  Have certificate             NaN  8600.0  102.38
# 1           <NA>               NaN             NaN  7500.0  125.00
# 2           <NA>     Sale contract             NaN  8900.0   98.89
# 3              3  Have certificate            Full  5350.0   99.07
# 4              4  Have certificate            Full  6900.0   75.00
# ...          ...               ...             ...     ...     ...
# 30224          2  Have certificate             NaN  4600.0   68.66
# 30225          3  Have certificate             NaN  4700.0  156.67
# 30226       <NA>  Have certificate           Basic  7500.0  108.07
# 30227       <NA>               NaN             NaN  9500.0   98.96
# 30228          4  Have certificate           Basic  3150.0   90.00
#
# [30229 rows x 13 columns]

# %% [markdown]
# # Xem xét mối liên hệ giữa giá nhà và số tầng
# Sử dụng seaborn để trình bày boxplot thể hiện mối quan hệ giá nhà theo số tầng

# %%
df['Floors'] = pd.Categorical(df['Floors'], 
                            categories=df.groupby('Floors')['Giá/m2'].mean().sort_values().index, ordered=True)

# Vẽ boxplot theo Số tầng
plt.figure(figsize=(8, 5))
sns.boxplot(x='Floors', y='Giá/m2', data=df, color = "#00A7F0")
plt.ylim(-10, 650)
plt.title('Phân phối giá nhà theo Số tầng')
plt.tight_layout()

# %% [markdown]
# # Nhận xét:
# Trong nguồn dữ liệu, số liệu dữ liệu về nhà có 9 tầng, 10 tầng chiếm số lượng quá nhỏ --> làm cho việc trình bày boxplot trở nên khó khăn và không thể hiện rõ mối liên hệ
# Các dữ liệu về các nhà có số tầng khác có xu hướng: *"Càng nhiều tầng thì giá càng cao"*
# *NOTE: vẫn xuất hiện các outliers, có thể do vị trí địa lý, các yếu tố khác nhưng nhìn chung các dữ liệu tuân theo quy tắc nhất định

# %%
df = df[df['Address'].map(df['Address'].value_counts()) > 2]

# %% [markdown]
# Do có nhiều dữ liệu chưa sạch (trình bày address ở nhiều định dạng) và address quá cụ thể nên không thể đưa ra những phân tích tổng quan cho tập dữ liệu nên lọc address qua Tỉnh/thành: Chỉ phân tích kỹ quận, huyện của thành phố HCM và Hà Nội; các tỉnh thành khác chỉ phân tích tổng quan ở cấp tỉnh

# %%
df['Address'] = df['Address'].str.split(', ').str[-2:].str.join(', ')
df['Address'] = df['Address'].str.replace(r'\s*TP\s*', 'Thành phố', regex=True)
df['Address'] = df['Address'].str.replace(r'HN|Hà Nội\.|Hà Nội\s*$', 'Hà Nội', regex=True)
df['Address'] = df['Address'].str.replace(r'TP\.HCM|TP Hồ Chí Minh\s*$', 'Thành phố Hồ Chí Minh', regex=True)
df['Address'] = df['Address'].str.strip()
df['Tỉnh/thành'] = df['Address'].str.split(', ').str[-1].str.strip()
df['Address'] = np.where(df['Tỉnh/thành'].isin(['Hà Nội', 'Hồ Chí Minh']), df['Address'], df['Tỉnh/thành'])
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_25780\1336471069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = df['Address'].str.split(', ').str[-2:].str.join(', ')
# C:\Users\admin\AppData\Local\Temp\ipykernel_25780\1336471069.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = df['Address'].str.replace(r'\s*TP\s*', 'Thành phố', regex=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_25780\1336471069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = df['Address'].str.replace(r'HN|Hà Nội\.|Hà Nội\s*$', 'Hà Nội', regex=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_25780\1336471069.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = df['Address'].str.replace(r'TP\.HCM|TP Hồ Chí Minh\s*$', 'Thành phố Hồ Chí Minh', regex=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_25780\1336471069.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = df['Address'].str.strip()
# C:\Users\admin\AppData\Local\Temp\ipykernel_25780\1336471069.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tỉnh/thành'] = df['Address'].str.split(', ').str[-1].str.strip()
# C:\Users\admin\AppData\Local\Temp\ipykernel_25780\1336471069.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = np.where(df['Tỉnh/thành'].isin(['Hà Nội', 'Hồ Chí Minh']), df['Address'], df['Tỉnh/thành'])
#                     Address  Area  Frontage  Access Road House direction  \
# 0                  Hưng Yên  84.0      <NA>         <NA>             NaN
# 1                  Hưng Yên  60.0      <NA>         <NA>             NaN
# 2                  Hưng Yên  90.0       6.0         13.0      Đông - Bắc
# 3       Gò Vấp, Hồ Chí Minh  54.0      <NA>          3.5       Tây - Nam
# 4       Gò Vấp, Hồ Chí Minh  92.0      <NA>         <NA>      Đông - Nam
# ...                     ...   ...       ...          ...             ...
# 30224   Gò Vấp, Hồ Chí Minh  67.0       4.1         16.0             NaN
# 30225     Long Biên, Hà Nội  30.0      <NA>         <NA>             NaN
# 30226  Thủ Đức, Hồ Chí Minh  69.4       4.0         15.0      Đông - Bắc
# 30227   Gò Vấp, Hồ Chí Minh  96.0      <NA>          8.0             NaN
# 30228      Hoài Đức, Hà Nội  35.0      <NA>         <NA>      Đông - Nam
#
#       Balcony direction Floors  Bedrooms  Bathrooms      Legal status  \
# 0                   NaN      4      <NA>       <NA>  Have certificate
# 1                   NaN      5      <NA>       <NA>               NaN
# 2            Đông - Bắc      5      <NA>       <NA>     Sale contract
# 3             Tây - Nam      2         2          3  Have certificate
# 4            Đông - Nam      2         4          4  Have certificate
# ...                 ...    ...       ...        ...               ...
# 30224               NaN      1         3          2  Have certificate
# 30225               NaN      5         3          3  Have certificate
# 30226        Đông - Bắc    NaN      <NA>       <NA>  Have certificate
# 30227               NaN      4      <NA>       <NA>               NaN
# 30228        Đông - Nam      5         3          4  Have certificate
#
#       Furniture state   Price  Giá/m2   Tỉnh/thành
# 0                 NaN  8600.0  102.38     Hưng Yên
# 1                 NaN  7500.0  125.00     Hưng Yên
# 2                 NaN  8900.0   98.89     Hưng Yên
# 3                Full  5350.0   99.07  Hồ Chí Minh
# 4                Full  6900.0   75.00  Hồ Chí Minh
# ...               ...     ...     ...          ...
# 30224             NaN  4600.0   68.66  Hồ Chí Minh
# 30225             NaN  4700.0  156.67       Hà Nội
# 30226           Basic  7500.0  108.07  Hồ Chí Minh
# 30227             NaN  9500.0   98.96  Hồ Chí Minh
# 30228           Basic  3150.0   90.00       Hà Nội
#
# [21120 rows x 14 columns]

# %%
df['Address'] = pd.Categorical(df['Address'], 
                             categories=df.groupby('Address')['Giá/m2'].mean().sort_values().index,
                             ordered=True)

# Vẽ boxplot theo Quận
plt.figure(figsize=(20, 10))
sns.boxplot(x='Address', y='Giá/m2', data=df, color = "#2DE4B6")
plt.xticks(rotation=90)
plt.ylim(-10, 650)
plt.title('Phân phối giá nhà theo Quận/Tỉnh, thành')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_25780\1637928881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = pd.Categorical(df['Address'],

# %% [markdown]
# # SỬ DỤNG MACHINE LEARNING ĐỂ DỰ ĐOÁN GIÁ NHÀ TẠI VIỆT NAM

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
import pandas as pd            
import numpy as np             
import seaborn as sns              
import matplotlib.pyplot as plt

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    df[["Address", "Frontage", "Legal status","Floors","Bedrooms","Area", "Access Road","Bathrooms", "House direction", "Balcony direction"]], df["Giá/m2"], 
    random_state = 0, test_size=0.3)

X_train_encoded = pd.get_dummies(X_train, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, drop_first=True)

X_train_encoded, X_test_encoded = X_train_encoded.align(X_test_encoded, join='left', axis=1, fill_value=0)

# Sử dụng Random Forest Model
rf_model = RandomForestRegressor(
    n_estimators = 100,    
    max_depth = 50,        
    max_features = 9,       
    random_state = 10,      
)

rf_model.fit(X_train_encoded, Y_train)

Y_pred = rf_model.predict(X_test_encoded)

X_test_display = X_test.copy()

X_test_display["Giá/m2_thực_tế"] = Y_test.values
X_test_display["Giá/m2_dự_đoán"] = Y_pred

print(X_test_display.head(10))
print(f"Sai số tuyệt đối trung bình: {mean_absolute_error(Y_test, Y_pred):.2f}")
print(f"Hệ số xác định (R²): {r2_score(Y_test, Y_pred):.3f}")
# Out:
#                      Address  Frontage      Legal status Floors  Bedrooms  \
# 11460  Bình Tân, Hồ Chí Minh       4.0               NaN      3      <NA>
# 8172      Đan Phượng, Hà Nội       5.0  Have certificate    NaN      <NA>
# 26327    Quận 6, Hồ Chí Minh       5.0               NaN    NaN      <NA>
# 3066    Quận 12, Hồ Chí Minh       4.0  Have certificate      2         4
# 28599        Đống Đa, Hà Nội      <NA>  Have certificate      5         9
# 14480  Bình Tân, Hồ Chí Minh      <NA>  Have certificate      2         2
# 3456         Đống Đa, Hà Nội       3.0  Have certificate      4         3
# 21457       Hoài Đức, Hà Nội       4.0  Have certificate      5         6
# 10829             Bình Dương      <NA>  Have certificate      2         3
# 9400    Quận 12, Hồ Chí Minh       4.0  Have certificate      3         4
#
#        Area  Access Road  Bathrooms House direction Balcony direction  \
# 11460  46.0         <NA>       <NA>             NaN               NaN
# 8172   75.0         10.0       <NA>       Tây - Nam         Tây - Nam
# 26327  42.6          6.0       <NA>             NaN               NaN
# 3066   57.8         12.0          4       Tây - Bắc               NaN
# 28599  43.0         <NA>          9             NaN               NaN
# 14480  50.0         <NA>          2            Đông               NaN
# 3456   37.0          2.0          3             NaN               NaN
# 21457  40.0          3.0          4             NaN               NaN
# 10829  75.0          7.0          2             NaN               NaN
# 9400   96.0         10.0          3             NaN               NaN
#
#        Giá/m2_thực_tế  Giá/m2_dự_đoán
# 11460          100.00      103.648247
# 8172            90.67       96.201503
# 26327          129.11      138.738075
# 3066            95.16       97.765130
# 28599          220.93      182.324889
# 14480          100.00       87.053194
# 3456           105.41      173.733073
# 21457           95.00       99.152005
# 10829           38.27       45.858215
# 9400            88.54       73.260660
# Sai số tuyệt đối trung bình: 18.71
# Hệ số xác định (R²): 0.678

# %% [markdown]
# ## Kết quả
# Dự đoán có sai số trung bình: ***18 - 19 triệu***

# %% [markdown]
# # TRỰC QUAN HÓA DỮ LIỆU

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    df[["Address", "Frontage", "Legal status","Floors","Bedrooms","Area", "Access Road","Bathrooms", "House direction", "Balcony direction"]], df["Giá/m2"], 
    random_state = 0, test_size=0.3)

X_train_encoded = pd.get_dummies(X_train, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, drop_first=True)


X_train_encoded, X_test_encoded = X_train_encoded.align(X_test_encoded, join='left', axis=1, fill_value=0)

# Sử dụng Random Forest Model
rf_model = RandomForestRegressor(
    n_estimators = 100,      
    max_depth = 50,       
    max_features = 9,        
    random_state = 10,      
)


rf_model.fit(X_train_encoded, Y_train)


Y_pred = rf_model.predict(X_test_encoded)

# Trực quan bằng matplotlib và seaborn
plt.figure(figsize=(10, 10))
sns.scatterplot(x=Y_test, y=Y_pred, c='g')


plt.plot([Y_test.min(), Y_test.max()],
         [Y_test.min(), Y_test.max()], color = "grey", linestyle='--')

mae = mean_absolute_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
plt.text(x=Y_test.min(), 
         y=Y_test.max()*0.95, 
         s=f"Sai số tuyệt đối trung bình: {mae:.2f}\nHệ số xác định: {r2:.3f}", 
         fontsize=10, 
         bbox=dict(facecolor='white', alpha=0.5))

plt.xlabel('Giá thực tế (Y_test)')
plt.ylabel('Giá dự đoán (Y_pred)')
plt.title('So sánh giá thực tế và giá dự đoán')
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# Hình ảnh trực quan dữ liệu khi zoom khu vực dữ liệu chính, loại bỏ outliers:

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x=Y_test, y=Y_pred, c='g')


plt.plot([Y_test.min(), Y_test.max()],
         [Y_test.min(), Y_test.max()], color = "red", linestyle='--')

mae = mean_absolute_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

plt.xlabel('Giá thực tế (Y_test)')
plt.text(x=0, y=450,
         s=f"Sai số tuyệt đối trung bình: {mae:.2f}\nHệ số xác định: {r2:.3f}", 
         fontsize=20, 
         bbox=dict(facecolor='white', alpha=0.5))
plt.xlim(-10,500)
plt.ylim(-10, 500)
plt.ylabel('Giá dự đoán (Y_pred)')
plt.title('So sánh giá thực tế và giá dự đoán')
plt.grid(True)
plt.tight_layout()
